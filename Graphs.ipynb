# %% [markdown]
# <a href="https://colab.research.google.com/github/ematteli/VisionProject/blob/main/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
 
 
# Creating dataset
labels = ['0', '1', '2']
colors = ['gold', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0)

 #26\% zeros, 22\% ones, 51\% twos
 #40\% zeros, 17\% ones, 39\% two
im2gps3k_percentage = [26, 22, 51]
yfcc4k_percentage = [40, 17, 39]

# Creating plot
fig = plt.plot(figsize =(5, 5))
#plt.pie(im2gps3k_percentage, labels = classes)
#plt.pie(im2gps3k_percentage, labels=labels, colors=colors,
#        autopct='%1.1f%%', shadow=True, startangle=140)
patches, texts = plt.pie(im2gps3k_percentage, colors=colors, labels=labels, labeldistance=0.5, shadow=False, startangle=90, 
                         wedgeprops = {"edgecolor" : "black", 'linewidth': 1.5, 'antialiased': True})
for text in texts:
    text.set_fontweight('bold')
    text.set_horizontalalignment('center')

plt.tight_layout()
# show plot
plt.show()

# %%
fig = plt.plot(figsize =(5, 5))
patches, texts = plt.pie(yfcc4k_percentage, colors=colors, labels=labels, labeldistance=0.5, shadow=False, startangle=90, 
                         wedgeprops = {"edgecolor" : "black", 'linewidth': 1.5, 'antialiased': True})
#plt.legend(patches, labels, loc="best")
for text in texts:
    text.set_fontweight('bold')
    text.set_horizontalalignment('center')
#plt.axis('equal')
plt.tight_layout()
# show plot
plt.show()

# %%
import seaborn as sns

# %%
labels = ['label 0', 'label 1', 'label 2']
sns.set(font_scale = 1.7)
plt.figure(figsize=(5,5))

plt.pie(
    x=im2gps3k_percentage, labels=labels,
    #colors=sns.color_palette('Set2'),
    colors = colors,
    startangle=90,
    # show percentages
    autopct='%1d%%',
    # move the percentage inside the arcs
    pctdistance=0.55,
    # add space between the arcs
    explode=[0.05, 0.05, 0.05],
    wedgeprops = {"edgecolor" : "black", 'linewidth': 1.2, 'antialiased': True}
)

### Add a hole in the pie  
#hole = plt.Circle((0, 0), 0.55, color='k', linewidth=1.2, fill=False)
#plt.gcf().gca().add_artist(hole)

plt.show()

# %%
labels = ['label 0', 'label 1', 'label 2']
sns.set(font_scale = 1.7)
plt.figure(figsize=(5,5))

plt.pie(
    x=yfcc4k_percentage, labels=labels,
    #colors=sns.color_palette('Set2'),
    colors = colors,
    startangle=90,
    # show percentages
    autopct='%1d%%',
    # move the percentage inside the arcs
    pctdistance=0.55,
    # add space between the arcs
    explode=[0.05, 0.05, 0.05],
    wedgeprops = {"edgecolor" : "black", 'linewidth': 1.2, 'antialiased': True}
)

### Add a hole in the pie  
#hole = plt.Circle((0, 0), 0.55, color='k', linewidth=1.2, fill=False)
#plt.gcf().gca().add_artist(hole)

plt.show()

# %%
labels = ['label 0', 'label 1', 'label 2']
sns.set(font_scale = 1.2)
plt.figure(figsize=(5,5))

plt.pie(
    x=im2gps3k_percentage, labels=labels,
    #colors=sns.color_palette('Set2'),
    colors = colors,
    startangle=90,
    # show percentages
    autopct='%1d%%',
    # move the percentage inside the arcs
    pctdistance=0.7,
    # add space between the arcs
    explode=[0.05, 0.05, 0.05]
    #wedgeprops = {"edgecolor" : "black", 'linewidth': 1.2, 'antialiased': True}
)

### Add a hole in the pie  
#hole = plt.Circle((0, 0), 0.55, facecolor='white', edgecolor='k', linewidth=1.2)
hole = plt.Circle((0, 0), 0.55, facecolor='white')
plt.gcf().gca().add_artist(hole)

plt.show()

# %%
from collections import Counter

# %%
continent_count = Counter({'NA': 830, 'EU': 793, 'AS': 233, 'OC': 58, 'SA': 58, 'AF': 26})

# %%
sum_values = sum(continent_count.values())

# %%
def percentuale(v):
  return v/1998 *100

# %%
percentuali_lista = list(map(percentuale, continent_count.values()))

# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
labels = continent_count.keys()
sns.set(font_scale = 1.7)
plt.figure(figsize=(6,6))

plt.pie(x=percentuali_lista, 
        #labels=labels,
        colors=sns.color_palette("Paired"),
    #colors =sns.color_palette("flare"),
    #colors = colors,
        startangle=90,
    # show percentages
                         #autopct='%1d%%',
    # move the percentage inside the arcs
        pctdistance=0.55,
    # add space between the arcs
        explode=[0.07, 0.07, 0.07, 0.07, 0.07, 0.07],
        wedgeprops = {"edgecolor" : "black", 'linewidth': 1.2, 'antialiased': True}
)
labels_full = ['North America', 'Europe', 'Asia', 'Oceania', 'South America', 'Africa']
#({'NA': 830, 'EU': 793, 'AS': 233, 'OC': 58, 'SA': 58, 'AF': 26})
### Add a hole in the pie  
#hole = plt.Circle((0, 0), 0.55, facecolor='white')
#plt.gcf().gca().add_artist(hole)
plt.legend(labels_full, bbox_to_anchor=(1.1, 0.85))

plt.show()
